86.684733697773 36.317973326831, -86.684699591776 36.317974151733, -86.684665507134 36.317973520632, -86.684631477793 36.317971433333, -86.68459763905 36.317967916542, -86.684564060918 36.317962970434, -86.684530877033 36.317956593108, -86.684498156464 36.317948839113, -86.684465966872 36.317939682313, -86.684434410539 36.317929174779, -86.684403588837 36.317917345124, -86.684373571297 36.317904219853, -86.684344459281 36.317889826434, -86.684326674234 36.317879990052, -86.684316287432 36.317874245935, -86.684302824084 36.317865914792, -86.684289191525 36.317857478161, -86.68426324764 36.317839571324, -86.684256102032 36.317834107592, -86.684238845727 36.317820888334, -86.684238467028 36.31782059976, -86.684214941205 36.317800597286, -86.684198087132 36.317784659146, -86.684192764759 36.31777962632, -86.684192703379 36.317779560856, -86.684171971159 36.317757713569, -86.684152631595 36.317734995979, -86.684134777648 36.317711445901, -86.684118584387 36.317687355353, -86.684118479798 36.317687199713, -86.684092188873 36.317669383506, -86.684065662977 36.317651788949, -86.684038935337 36.31763441471, -86.684012006185 36.317617205848, -86.683984908062 36.317600245732, -86.683957575439 36.317583479794, -86.683930039415 36.31756690614, -86.683902337016 36.317550554321, -86.683874432164 36.317534422822, -86.683846359508 36.317518511448, ...

# %% [markdown]
# #### Plotting a GeoDataFrame is as easy as calling the GeoPandas .plot() function

# %%
zipcodes.plot();

# %% [markdown]
# #### Add information and styling
# - set the `column =` to a column in the GeoDataFrame to color by
# - change the [colormap](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html)
# - pass in keywords to tweak the legend created by [`matplotib`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)

# %%
#geopandas will take care of legend styling if you pass a dict of keywords

leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 2}

zipcodes.plot(column = 'zip', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')
plt.show()

# %% [markdown]
# #### Next you will read in the bus stop data
# - downloaded from https://data.nashville.gov/Transportation/Regional-Transportation-Authority-Bus-Stops/p886-fnbd
# - cleaned:
#     - rename columns
#     - drop unwanted columns
#     - parse `lat` and `lng` columns from `location`
# - print the shape
# - take a look at the first 3 rows

# %%
beer_stops = pd.read_csv('../data/Beer_Permit_Locations.csv')
print(beer_stops.shape)
beer_stops.head(3)
# Out:
# (2032, 21)
#    OBJECTID  Permit #  Status Permit Type Permit SubType  \
# 0         1  21-27149  ISSUED    BBPERMIT        ONSALES
# 1         2  21-27151  ISSUED    BBPERMIT     ONOFFSALES
# 2         3  21-27153  ISSUED    BBPERMIT        ONSALES
#
#   Permit SubType Description         Date Entered           Date Issued  \
# 0         BB - On Site Sales  4/1/2021 5:00:00 AM  7/29/2021 5:00:00 AM
# 1   BB - On & Off Site Sales  4/2/2021 5:00:00 AM  7/29/2021 5:00:00 AM
# 2         BB - On Site Sales  4/5/2021 5:00:00 AM  9/15/2022 5:00:00 AM
#
#         Parcel          Business Name  ...                   Address  \
# 0  10308006000    LOLA NASHVILLE, LLC  ...         4401  MURPHY RD
# 1  07207029200  BITE A BIT THAI SUSHI  ...     1402  MCGAVOCK PIKE
# 2  13314008900        404 BAR & GRILL  ...  404  ELYSIAN FIELDS RD
#
#         City State Zip Code  Council District  Census Tract        Lon  \
# 0  NASHVILLE    TN  37209.0                24      37013400 -86.839203
# 1  NASHVILLE    TN  37216.0                 7      37011500 -86.723963
# 2  NASHVILLE    TN  37211.0                26      37018901 -86.731159
#
#          Lat          x          y
# 0  36.140724 -86.839203  36.140724
# 1  36.204799 -86.723963  36.204799
# 2  36.086771 -86.731159  36.086771
#
# [3 rows x 21 columns]

# %%
beer_stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2032 entries, 0 to 2031
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   OBJECTID                    2032 non-null   int64
#  1   Permit #                    2032 non-null   object
#  2   Status                      2032 non-null   object
#  3   Permit Type                 2032 non-null   object
#  4   Permit SubType              2032 non-null   object
#  5   Permit SubType Description  2032 non-null   object
#  6   Date Entered                2032 non-null   object
#  7   Date Issued                 1980 non-null   object
#  8   Parcel                      2032 non-null   object
#  9   Business Name               2031 non-null   object
#  10  Business Owner              1037 non-null   object
#  11  Address                     2032 non-null   object
#  12  City                        2032 non-null   object
#  13  State                       2032 non-null   object
#  14  Zip Code                    2031 non-null   float64
#  15  Council District            2032 non-null   int64
#  16  Census Tract                2032 non-null   int64
#  17  Lon                         2032 non-null   float64
#  18  Lat                         2032 non-null   float64
#  19  x                           2032 non-null   float64
#  20  y                           2032 non-null   float64
# dtypes: float64(5), int64(3), object(13)
# memory usage: 333.5+ KB

# %% [markdown]
# - you want the CRS for the bus stops to match the CRS in the zipcodes GeoDataFrame

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### The `GeoDataFrame()` constructor needs 3 parameters:
#  - a DataFrame
#  - a coordinate reference system
#  - a geometry (we will use the geopandas `points_from_xy()` method to create a Point geometry)

# %%
beer_geo = gpd.GeoDataFrame(beer_stops, 
                           crs = zipcodes.crs, 
                           geometry = gpd.points_from_xy(beer_stops.Lon, beer_stops.Lat))

# %%
type(beer_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# #### Now you are ready to combine bus stops and zipcodes with a spatial join
# - first a little clean up for the zipcodes
#     - just keep the zip, po_name, and geometry columns
# - then construct the join
#     - keep in mind that you want to find the **bus stops within a zip code polygon**
#     - the geometry for the new (combined) GeoDataFrame comes from the left GeoDataFrame

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
shops_by_zip = gpd.sjoin(beer_geo, zipcodes, predicate = 'within')

# %%
shops_by_zip.head()
# Out:
#    OBJECTID  Permit #  Status Permit Type Permit SubType  \
# 0         1  21-27149  ISSUED    BBPERMIT        ONSALES
# 1         2  21-27151  ISSUED    BBPERMIT     ONOFFSALES
# 2         3  21-27153  ISSUED    BBPERMIT        ONSALES
# 3         4  21-27157  ISSUED    BBPERMIT        ONSALES
# 4         5  21-27171  ISSUED    BBPERMIT        ONSALES
#
#   Permit SubType Description          Date Entered           Date Issued  \
# 0         BB - On Site Sales   4/1/2021 5:00:00 AM  7/29/2021 5:00:00 AM
# 1   BB - On & Off Site Sales   4/2/2021 5:00:00 AM  7/29/2021 5:00:00 AM
# 2         BB - On Site Sales   4/5/2021 5:00:00 AM  9/15/2022 5:00:00 AM
# 3         BB - On Site Sales   4/9/2021 5:00:00 AM  6/10/2021 5:00:00 AM
# 4         BB - On Site Sales  4/14/2021 5:00:00 AM  1/13/2022 6:00:00 AM
#
#            Parcel                      Business Name  ... Council District  \
# 0     10308006000                LOLA NASHVILLE, LLC  ...               24
# 1     07207029200              BITE A BIT THAI SUSHI  ...                7
# 2     13314008900                    404 BAR & GRILL  ...               26
# 3  093130C80100CO                    SUNDA NEW ASIAN  ...               19
# 4     09109003200  TEE LINE CURLING & BOWLING CENTER  ...               20
#
#   Census Tract        Lon        Lat          x          y  \
# 0     37013400 -86.839203  36.140724 -86.839203  36.140724
# 1     37011500 -86.723963  36.204799 -86.723963  36.204799
# 2     37018901 -86.731159  36.086771 -86.731159  36.086771
# 3     37019500 -86.784013  36.151893 -86.784013  36.151893
# 4     37013202 -86.867446  36.157813 -86.867446  36.157813
#
#                      geometry  index_right    zip    po_name
# 0  POINT (-86.83920 36.14072)           12  37209  NASHVILLE
# 1  POINT (-86.72396 36.20480)            1  37216  NASHVILLE
# 2  POINT (-86.73116 36.08677)           49  37211  NASHVILLE
# 3  POINT (-86.78401 36.15189)           35  37203  NASHVILLE
# 4  POINT (-86.86745 36.15781)           12  37209  NASHVILLE
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Now that the data is joined spatially you can count the bus stops by zip code  and see how many stops are within each polygon
# - using the `value_counts()` method

# %%
shops_by_zip['zip'].value_counts()
# Out:
# zip
# 37203    308
# 37214    215
# 37211    170
# 37209    143
# 37206    128
# 37013    101
# 37201     97
# 37207     91
# 37115     79
# 37217     74
# 37076     66
# 37221     66
# 37208     61
# 37210     50
# 37204     46
# 37215     46
# 37216     46
# 37219     41
# 37212     38
# 37205     37
# 37138     28
# 37027     26
# 37218     22
# 37080     13
# 37213     10
# 37228      8
# 37189      7
# 37072      7
# 37220      2
# 37135      2
# 37240      2
# 37086      1
# 37232      1
# Name: count, dtype: int64

# %% [markdown]
# #### Let's take a closer look at the 272 bus stops in the 37207 zip code
# - filter the stops_by_zip data to just get bus stops in 37207
# - filter the zip code geodataframe to just the polygon (row) for 37207

# %%
shops_in_37203 = shops_by_zip.loc[shops_by_zip['zip'] == '37203']
shops_in_37203.shape
# Out:
# (308, 25)

# %%
polygon37203 = zipcodes.loc[zipcodes['zip'] == '37203']
polygon37203.shape
# Out:
# (1, 3)

# %% [markdown]
# #### Now plot these two together
# - first plot the polygons for 37207 and make them light green
# - next plot the points for the bus stops and color them by route

# %%
#fig, ax = matplotlib.subplots()
ax = polygon37203.plot(figsize = (8, 10), color = 'lightgreen')
shops_in_37203.plot( ax = ax, column = 'Business Name');
plt.show();

# %% [markdown]
# #### We're getting there! It would be helpful to have streets, though wouldn't it? We can add a street map with the folium package.

# %% [markdown]
# #### folium maps require a center point for the street map.
# - Make use of a GeoSeries attribute (.centroid) which gives the center of a polygon
# - Since there are two polygons which should we use?

# %%
polygon37203.geometry.centroid
# Out:
# C:\Users\ekims\AppData\Local\Temp\ipykernel_5960\651956959.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon37203.geometry.centroid
# 35    POINT (-86.78899 36.14860)
# dtype: geometry

# %%
#find the center of the larger (more southern) polygon and look at it
center = polygon37203.geometry.centroid[35]
print(center)
# Out:
# POINT (-86.7889889966741 36.14860232841574)
# C:\Users\ekims\AppData\Local\Temp\ipykernel_5960\3545517365.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = polygon37203.geometry.centroid[35]

# %% [markdown]
# #### Folium requires a location point as an array
# - with *latitude* first
# - but shapely Points have *longitude* first

# %%
# reverse the order when constructing the array for folium location
area_center = [center.y, center.x]

# check the order of area_center, the location for our folium map
print(area_center)
# Out:
# [36.14860232841574, -86.7889889966741]

# %% [markdown]
# #### To create a folium map just call the folium `Map()` constructor
# - `location` is the only argument required by the constructor
#     - Set `area_center` as the `location` of the folium map.
# - `zoom_start` is an optional argument
#     - A setting of 12 should get us nice and close

# %%
#create our map of Nashville Zip Code 37207 and show it
map_37203 = folium.Map(location =  area_center, zoom_start = 12)
map_37203
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c5cac32890110c3470592c85b6c0823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c5cac32890110c3470592c85b6c0823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c5cac32890110c3470592c85b6c0823 = L.map(
#                 &quot;map_4c5cac32890110c3470592c85b6c0823&quot;,
#                 {
#                     center: [36.14860232841574, -86.7889889966741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e635f054825b051bb50e2327ff77736 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e635f054825b051bb50e2327ff77736.addTo(map_4c5cac32890110c3470592c85b6c0823);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Next, let's add our 37207 polygon and bus stop markers.

# %% [markdown]
# #### `itterows()` is a generator that iterates through the rows of a DataFrame and returns a tuple with the row id and row values.
# - Below, we are printing the row values for the first 3 row as we iterate through the GeoDataFrame of bus stops in 37207.
# - This idea will be helpful for creating our markers!

# %%
i = 0
for row_index, row_values in shops_in_37203.iterrows():
    if i <3: 
        print('index is', row_index)
        print('values are:')
        print(' ')
        print(row_values)
        print('------------------------- ')
        i+=1
# Out:
# index is 3
# values are:
#
# OBJECTID                                                     4
# Permit #                                              21-27157
# Status                                                  ISSUED
# Permit Type                                           BBPERMIT
# Permit SubType                                         ONSALES
# Permit SubType Description                  BB - On Site Sales
# Date Entered                               4/9/2021 5:00:00 AM
# Date Issued                               6/10/2021 5:00:00 AM
# Parcel                                          093130C80100CO
# Business Name                                  SUNDA NEW ASIAN
# Business Owner                                             NaN
# Address                                       592  12TH AVE S
# City                                                 NASHVILLE
# State                                                       TN
# Zip Code                                               37203.0
# Council District                                            19
# Census Tract                                          37019500
# Lon                                                 -86.784013
# Lat                                                  36.151893
# x                                                   -86.784013
# y                                                    36.151893
# geometry                      POINT (-86.78401339 36.15189307)
# index_right                                                 35
# zip                                                      37203
# po_name                                              NASHVILLE
# Name: 3, dtype: object
# -------------------------
# index is 7
# values are:
#
# OBJECTID                                                     8
# Permit #                                              21-27179
# Status                                                  ISSUED
# Permit Type                                           BBPERMIT
# Permit SubType                                      ONOFFSALES
# Permit SubType Description            BB - On & Off Site Sales
# Date Entered                              4/20/2021 5:00:00 AM
# Date Issued                               4/28/2022 5:00:00 AM
# Parcel                                          093050A00100CO
# Business Name                          L20 HEARTBREAKER LOUNGE
# Business Owner                                             NaN
# Address                               101  PLATFORM WAY N 2000
# City                                                 NASHVILLE
# State                                                       TN
# Zip Code                                               37203.0
# Council District                                            19
# Census Tract                                          37019500
# Lon                                                 -86.786514
# Lat                                                  36.160754
# x                                                   -86.786514
# y                                                    36.160754
# geometry                      POINT (-86.78651406 36.16075416)
# index_right                                                 35
# zip                                                      37203
# po_name                                              NASHVILLE
# Name: 7, dtype: object
# -------------------------
# index is 18
# values are:
#
# OBJECTID                                                       19
# Permit #                                                 21-27233
# Status                                                     ISSUED
# Permit Type                                              BBPERMIT
# Permit SubType                                            ONSALES
# Permit SubType Description                     BB - On Site Sales
# Date Entered                                 5/10/2021 5:00:00 AM
# Date Issued                                  7/26/2021 5:00:00 AM
# Parcel                                             093063A00300CO
# Business Name                 SLIM + HUSKY'S FIFTH & BROADWAY LLC
# Business Owner                                         Clint Gray
# Address                                       5056  BROADWAY PL
# City                                                    NASHVILLE
# State                                                          TN
# Zip Code                                                  37203.0
# Council District                                               19
# Census Tract                                             37019500
# Lon                                                    -86.779741
# Lat                                                     36.160409
# x                                                      -86.779741
# y                                                       36.160409
# geometry                         POINT (-86.77974101 36.16040892)
# index_right                                                    35
# zip                                                         37203
# po_name                                                 NASHVILLE
# Name: 18, dtype: object
# -------------------------

# %% [markdown]
# #### Create map_37207 again with additional features:
# - add the zipcode area outline (polygon_37207)
# - iterate through the stops_in_37207 to
#     - create location from each lat and lng
#     - create a popup from the stop column
#     - create a custom icon if you want with [font-awesome](https://fontawesome.com/v4.7.0/icons/)
#     - build a marker from each location and popup and (optionally) your custom icon
#     - add the marker to  `map_37207`
# - display `map_37207`

# %%
#draw our zip code area: 37207
map_37203 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37203).add_to(map_37203)

#iterate through stops_in_37207 to create locations and markers 
#for each bus stop
#remember for Folium locations, lat is listed first!!

for row_index, row_values in shops_in_37203.iterrows():
    loc = [row_values['Lat'], row_values['Lon']]
    pop = str(row_values['Business Name'])
    icon=folium.Icon(color="beige",icon="beer", prefix='fa')
    
    marker = folium.Marker(
        location = loc,
        popup = pop, icon = icon) 

    marker.add_to(map_37203)
map_37203.save('../maps/map37203.html')

#display our map
map_37203
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4edff19d944aad1c210298c2183d3fbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4edff19d944aad1c210298c2183d3fbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4edff19d944aad1c210298c2183d3fbb = L.map(
#                 &quot;map_4edff19d944aad1c210298c2183d3fbb&quot;,
#                 {
#                     center: [36.14860232841574, -86.7889889966741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5009dbda0fb6d61162e8bc5063fc0af2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5009dbda0fb6d61162e8bc5063fc0af2.addTo(map_4edff19d944aad1c210298c2183d3fbb);
#
#
#
#         function geo_json_86d8bc1465e9604bf7b3ab0a078355f8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_86d8bc1465e9604bf7b3ab0a078355f8 = L.geoJson(null, {
#                 onEachFeature: geo_json_86d8bc1465e9604bf7b3ab0a078355f8_onEachFeature,
#
#         });
#
#         function geo_json_86d8bc1465e9604bf7b3ab0a078355f8_add (data) {
#             geo_json_86d8bc1465e9604bf7b3ab0a078355f8
#                 .addData(data);
#         }
#             geo_json_86d8bc1465e9604bf7b3ab0a078355f8_add({&quot;bbox&quot;: [-86.822823465644, 36.125805265376, -86.758598341656, 36.170177158253], &quot;features&quot;: [{&quot;bbox&quot;: [-86.822823465644, 36.125805265376, -86.758598341656, 36.170177158253], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[
# %% [markdown]
# #### If you have a lot of markers, you might want to use marker clusters
# - Folium has `MarkerCluster()` and `FastMarkerCluster()`
# - Construct a `MarkerCluster()`
#     - construct a `MarkerCluster()` and `.add_to()` the map
#     - when you loop through the data and create markers add those to the marker cluster
# - Construct a `FastMarkerCluster()` by passing a list of locations

# %% [markdown]
# #### You can save your map as an html file and it will retain the interactive qualities

# %%
folium.Map?
# Out:
# Init signature:
# folium.Map(
#     location: Optional[Sequence[float]] = None,
#     width: Union[str, float] = '100%',
#     height: Union[str, float] = '100%',
#     left: Union[str, float] = '0%',
#     top: Union[str, float] = '0%',
#     position: str = 'relative',
#     tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap',
#     attr: Optional[str] = None,
#     min_zoom: int = 0,
#     max_zoom: int = 18,
#     zoom_start: int = 10,
#     min_lat: int = -90,
#     max_lat: int = 90,
#     min_lon: int = -180,
#     max_lon: int = 180,
#     max_bounds: bool = False,
#     crs: str = 'EPSG3857',
#     control_scale: bool = False,
#     prefer_canvas: bool = False,
#     no_touch: bool = False,
#     disable_3d: bool = False,
#     png_enabled: bool = False,
#     zoom_control: bool = True,
#     **kwargs: Union[str, float, bool, Sequence, dict, NoneType],
# )
# Docstring:
# Create a Map with Folium and Leaflet.js
#
# Generate a base map of given width and height with either default
# tilesets or a custom tileset URL. Folium has built-in all tilesets
# available in the ``xyzservices`` package. For example, you can pass
# any of the following to the "tiles" keyword:
#
#     - "OpenStreetMap"
#     - "CartoDB Positron"
#     - "CartoBD Voyager"
#     - "NASAGIBS Blue Marble"
#
# You can pass a custom tileset to Folium by passing a
# :class:`xyzservices.TileProvider` or a Leaflet-style
# URL to the tiles parameter: ``http://{s}.yourtiles.com/{z}/{x}/{y}.png``.
#
# You can find a list of free tile providers here:
# ``http://leaflet-extras.github.io/leaflet-providers/preview/``.
# Be sure to check their terms and conditions and to provide attribution
# with the `attr` keyword.
#
# Parameters
# ----------
# location: tuple or list, default None
#     Latitude and Longitude of Map (Northing, Easting).
# width: pixel int or percentage string (default: '100%')
#     Width of the map.
# height: pixel int or percentage string (default: '100%')
#     Height of the map.
# tiles: str or TileLayer or :class:`xyzservices.TileProvider`, default 'OpenStreetMap'
#     Map tileset to use. Can choose from a list of built-in tiles,
#     pass a :class:`xyzservices.TileProvider`,
#     pass a custom URL, pass a TileLayer object,
#     or pass `None` to create a map without tiles.
#     For more advanced tile layer options, use the `TileLayer` class.
# min_zoom: int, default 0
#     Minimum allowed zoom level for the tile layer that is created.
# max_zoom: int, default 18
#     Maximum allowed zoom level for the tile layer that is created.
# zoom_start: int, default 10
#     Initial zoom level for the map.
# attr: string, default None
#     Map tile attribution; only required if passing custom tile URL.
# crs : str, default 'EPSG3857'
#     Defines coordinate reference systems for projecting geographical points
#     into pixel (screen) coordinates and back.
#     You can use Leaflet's values :
#     * EPSG3857 : The most common CRS for online maps, used by almost all
#     free and commercial tile providers. Uses Spherical Mercator projection.
#     Set in by default in Map's crs option.
#     * EPSG4326 : A common CRS among GIS enthusiasts.
#     Uses simple Equirectangular projection.
#     * EPSG3395 : Rarely used by some commercial tile providers.
#     Uses Elliptical Mercator projection.
#     * Simple : A simple CRS that maps longitude and latitude into
#     x and y directly. May be used for maps of flat surfaces
#     (e.g. game maps). Note that the y axis should still be inverted
#     (going from bottom to top).
# control_scale : bool, default False
#     Whether to add a control scale on the map.
# prefer_canvas : bool, default False
#     Forces Leaflet to use the Canvas back-end (if available) for
#     vector layers instead of SVG. This can increase performance
#     considerably in some cases (e.g. many thousands of circle
#     markers on the map).
# no_touch : bool, default False
#     Forces Leaflet to not use touch events even if it detects them.
# disable_3d : bool, default False
#     Forces Leaflet to not use hardware-accelerated CSS 3D
#     transforms for positioning (which may cause glitches in some
#     rare environments) even if they're supported.
# zoom_control : bool, default True
#     Display zoom controls on the map.
# **kwargs
#     Additional keyword arguments are passed to Leaflets Map class:
#     https://leafletjs.com/reference.html#map
#
# Returns
# -------
# Folium Map Object
#
# Examples
# --------
# >>> m = folium.Map(location=[45.523, -122.675], width=750, height=500)
# >>> m = folium.Map(location=[45.523, -122.675], tiles="cartodb positron")
# >>> m = folium.Map(
# ...     location=[45.523, -122.675],
# ...     zoom_start=2,
# ...     tiles="https://api.mapbox.com/v4/mapbox.streets/{z}/{x}/{y}.png?access_token=mytoken",
# ...     attr="Mapbox attribution",
# ... )
# File:           c:\users\ekims\anaconda3\envs\geospatial\lib\site-packages\folium\folium.py
# Type:           type
# Subclasses:

# %%
cluster_map_37203 = folium.Map(location =  area_center, zoom_start = 12)

#create a marker cluster
marker_cluster = MarkerCluster().add_to(cluster_map_37203)

folium.GeoJson(polygon37203).add_to(cluster_map_37203)

# inside the loop add each marker to the cluster
for row_index, row_values in shops_in_37203.iterrows():
    loc = [row_values['Lat'], row_values['Lon']]
    pop = str(row_values['Business Name'])
    icon=folium.Icon(color="beige",icon="beer", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop,
    icon = icon) 
    
    marker.add_to(marker_cluster)

    
#save an interactive HTML map by calling .save()
cluster_map_37203.save('../maps/cluster37203.html')

cluster_map_37203
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e23fe0d5db0b8139d2a5750766b563d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e23fe0d5db0b8139d2a5750766b563d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e23fe0d5db0b8139d2a5750766b563d = L.map(
#                 &quot;map_1e23fe0d5db0b8139d2a5750766b563d&quot;,
#                 {
#                     center: [36.14860232841574, -86.7889889966741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1de1dd6a4cd2cd384c5dc2ed1b0e9314 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1de1dd6a4cd2cd384c5dc2ed1b0e9314.addTo(map_1e23fe0d5db0b8139d2a5750766b563d);
#
#
#             var marker_cluster_51afcb48ba19a39df8797e5ee4f2f3e5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_a9a9d542725e2b2018251a11b42f0b83 = L.marker(
#                 [36.15189307, -86.78401339],
#                 {}
#             ).addTo(marker_cluster_51afcb48ba19a39df8797e5ee4f2f3e5);
#
#
#             var icon_7894ec01a59e9079738e4ae572adad99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a9a9d542725e2b2018251a11b42f0b83.setIcon(icon_7894ec01a59e9079738e4ae572adad99);
#
#
#         var popup_d488ee2046860c9d736a9c70c98f1b3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48c63ebb8ff644b768155f787f98548d = $(`&lt;div id=&quot;html_48c63ebb8ff644b768155f787f98548d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SUNDA NEW ASIAN&lt;/div&gt;`)[0];
#                 popup_d488ee2046860c9d736a9c70c98f1b3b.setContent(html_48c63ebb8ff644b768155f787f98548d);
#
#
#
#         marker_a9a9d542725e2b2018251a11b42f0b83.bindPopup(popup_d488ee2046860c9d736a9c70c98f1b3b)
#         ;
#
#
#
#
#             var marker_991460c94e09986cfd4384cf23ca1aad = L.marker(
#                 [36.16075416, -86.78651406],
#                 {}
#             ).addTo(marker_cluster_51afcb48ba19a39df8797e5ee4f2f3e5);
#
#
#             var icon_a968d7a17b5c354acd60e04bb7843890 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_991460c94e09986cfd4384cf23ca1aad.setIcon(icon_a968d7a17b5c354acd60e04bb7843890);
#
#
#         var popup_d42d0736bc3cf99695b09af0d61dff80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa69541f29f01c53d1a49c90d4f5235b = $(`&lt;div id=&quot;html_fa69541f29f01c53d1a49c90d4f5235b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L20 HEARTBREAKER LOUNGE&lt;/div&gt;`)[0];
#                 popup_d42d0736bc3cf99695b09af0d61dff80.setContent(html_fa69541f29f01c53d1a49c90d4f5235b);
#
#
#
#         marker_991460c94e09986cfd4384cf23ca1aad.bindPopup(popup_d42d0736bc3cf99695b09af0d61dff80)
#         ;
#
#
#
#
#             var marker_191c1b5f1cf487acd51d86349dff6c6a = L.marker(
#                 [36.16040892, -86.77974101],
#                 {}
#             ).addTo(marker_cluster_51afcb48ba19a39df8797e5ee4f2f3e5);
#
#
#             var icon_24c1a1bf91fc71192a21eaaa5471eee5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_191c1b5f1cf487acd51d86349dff6c6a.setIcon(icon_24c1a1bf91fc71192a21eaaa5471eee5);
#
#
#         var popup_74cea6540fba74e3556df2f46d5165fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6cd9da8bb16d91ae538fd4448840d85 = $(`&lt;div id=&quot;html_a6cd9da8bb16d91ae538fd4448840d85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SLIM + HUSKY&#x27;S FIFTH &amp; BROADWAY LLC&lt;/div&gt;`)[0];
#                 popup_74cea6540fba74e3556df2

# %%
#draw our zip code area: 37207
map_37203 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37203).add_to(map_37203)

#create a list of locations and pass them to FastMarkerCluster()
locations = shops_in_37203[['Lat', 'Lon']].values.tolist()
map_37203.add_child(
    FastMarkerCluster(locations)
)



#display our map
map_37203
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92b6c09cd6aaa19596a7a7e1d8664ff6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92b6c09cd6aaa19596a7a7e1d8664ff6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92b6c09cd6aaa19596a7a7e1d8664ff6 = L.map(
#                 &quot;map_92b6c09cd6aaa19596a7a7e1d8664ff6&quot;,
#                 {
#                     center: [36.14860232841574, -86.7889889966741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e91fad0cf643cdb0bbaed5ce1327cdfa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e91fad0cf643cdb0bbaed5ce1327cdfa.addTo(map_92b6c09cd6aaa19596a7a7e1d8664ff6);
#
#
#
#         function geo_json_6cf91350e241c8911f430809e22f1b83_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_